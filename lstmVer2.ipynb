# %%
import pandas as pd

# %%
df = pd.read_csv("DEXTAUS.csv")
df.head()
# Out:
#          DATE  DEXTAUS
# 0  2010-10-12  30.9800
# 1  2010-10-13  30.8400
# 2  2010-10-14  30.6600
# 3  2010-10-15  30.6600
# 4  2010-10-18  30.7500

# %%
df.shape
# Out:
# (2609, 2)

# %%
df = df[~df['DEXTAUS'].isin(["."])]

# %%
df.shape
# Out:
# (2504, 2)

# %%
df["DEXTAUS"] = df["DEXTAUS"].astype(float)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size

# %%
plt.title('Exchange rate TW & US')
plt.ylabel('Rate')
plt.xlabel('Day')
plt.grid(True)
plt.autoscale(axis='x',tight=True)
plt.plot(df['DEXTAUS'])
# Out:
# findfont: Font family ['Microsoft JhengHei'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Microsoft JhengHei'] not found. Falling back to DejaVu Sans.

# %%
rate = df.DEXTAUS.values
rate
# Out:
# array([30.98, 30.84, 30.66, ..., 28.66, 28.65, 28.62])

# %%
#決定訓練集與測試集大小
test_data_size = 504

train_data = rate[:-test_data_size]
test_data = rate[-test_data_size:]

# %%
print(len(train_data))
print(len(test_data))
# Out:
# 2000
# 504

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))
train_data_normalized = scaler.fit_transform(train_data .reshape(-1, 1))

# %%
print(train_data_normalized[:5])
print(train_data_normalized[-5:])
# Out:
# [[-0.05343511]
#  [-0.10687023]
#  [-0.17557252]
#  [-0.17557252]
#  [-0.14122137]]
# [[-0.17938931]
#  [-0.22900763]
#  [-0.2519084 ]
#  [-0.22137405]
#  [-0.21755725]]

# %%
import torch
import torch.nn as nn
import numpy as np

# %%
#torch.cuda.is_available()

# %%
#轉換為張量
train_data_normalized = torch.FloatTensor(train_data_normalized).view(-1)

# %%
#30天一循環
train_cicle = 30

# %%
def create_inout_sequences(input_data, tw):
    inout_seq = []
    L = len(input_data)
    for i in range(L-tw):
        train_seq = input_data[i:i+tw]
        train_label = input_data[i+tw:i+tw+1]
        inout_seq.append((train_seq ,train_label))
    return inout_seq

# %%
train_inout_seq = create_inout_sequences(train_data_normalized, train_cicle)

# %%
train_inout_seq[:5]
# Out:
# [(tensor([-0.0534, -0.1069, -0.1756, -0.1756, -0.1412, -0.0878, -0.1107, -0.1450,
#           -0.1107, -0.2672, -0.1794, -0.1450, -0.1870, -0.1985, -0.2366, -0.2557,
#           -0.2672, -0.3626, -0.3550, -0.3588, -0.3740, -0.3817, -0.3435, -0.3550,
#           -0.3321, -0.2595, -0.3244, -0.3244, -0.3702, -0.2328]),
#   tensor([-0.2595])),
#  (tensor([-0.1069, -0.1756, -0.1756, -0.1412, -0.0878, -0.1107, -0.1450, -0.1107,
#           -0.2672, -0.1794, -0.1450, -0.1870, -0.1985, -0.2366, -0.2557, -0.2672,
#           -0.3626, -0.3550, -0.3588, -0.3740, -0.3817, -0.3435, -0.3550, -0.3321,
#           -0.2595, -0.3244, -0.3244, -0.3702, -0.2328, -0.2595]),
#   tensor([-0.2519])),
#  (tensor([-0.1756, -0.1756, -0.1412, -0.0878, -0.1107, -0.1450, -0.1107, -0.2672,
#           -0.1794, -0.1450, -0.1870, -0.1985, -0.2366, -0.2557, -0.2672, -0.3626,
#           -0.3550, -0.3588, -0.3740, -0.3817, -0.3435, -0.3550, -0.3321, -0.2595,
#           -0.3244, -0.3244, -0.3702, -0.2328, -0.2595, -0.2519]),
#   tensor([-0.2290])),
#  (tensor([-0.1756, -0.1412, -0.0878, -0.1107, -0.1450, -0.1107, -0.2672, -0.1794,
#           -0.1450, -0.1870, -0.1985, -0.2366, -0.2557, -0.2672, -0.3626, -0.3550,
#           -0.3588, -0.3740, -0.3817, -0.3435, -0.3550, -0.3321, -0.2595, -0.3244,
#           -0.3244, -0.3702, -0.2328, -0.2595, -0.2519, -0.2290]),
#   tensor([-0.2481])),
#  (tensor([-0.1412, -0.0878, -0.1107, -0.1450, -0.1107, -0.2672, -0.1794, -0.1450,
#           -0.1870, -0.1985, -0.2366, -0.2557, -0.2672, -0.3626, -0.3550, -0.3588,
#           -0.3740, -0.3817, -0.3435, -0.3550, -0.3321, -0.2595, -0.3244, -0.3244,
#           -0.3702, -0.2328, -0.2595, -0.2519, -0.2290, -0.2481]),
#   tensor([-0.2863]))]

# %%
class LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_layer_size=100, output_size=1):
        super().__init__()
        
        self.hidden_layer_size = hidden_layer_size

        self.lstm = nn.LSTM(input_size, hidden_layer_size)

        self.linear = nn.Linear(hidden_layer_size, output_size)

        self.hidden_cell = (torch.zeros(1,1,self.hidden_layer_size),
                            torch.zeros(1,1,self.hidden_layer_size))

        
    def forward(self, input_seq):
        
        lstm_out, self.hidden_cell = self.lstm(input_seq.view(len(input_seq) ,1, -1), self.hidden_cell)
        predictions = self.linear(lstm_out.view(len(input_seq), -1))
        
        return predictions[-1]

# %%
#optimizer
model = LSTM()
#model.cuda()

loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
print(model)
# Out:
# LSTM(
#   (lstm): LSTM(1, 100)
#   (linear): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
epochs = 100

for i in range(epochs):
    for seq, labels in train_inout_seq:
        optimizer.zero_grad()
        model.hidden_cell = (torch.zeros(1, 1, model.hidden_layer_size),
                        torch.zeros(1, 1, model.hidden_layer_size))

        y_pred = model(seq)

        single_loss = loss_function(y_pred, labels)
        single_loss.backward()
        optimizer.step()

    if i%25 == 1:
        print(f'epoch: {i:3} loss: {single_loss.item():10.8f}')

print(f'epoch: {i:3} loss: {single_loss.item():10.10f}')
# Out:
# epoch:   1 loss: 0.00182106
# epoch:  26 loss: 0.00036871
# epoch:  51 loss: 0.00012644
# epoch:  76 loss: 0.00008551
# epoch:  99 loss: 0.0000364054

# %%
fut_pred = 504

test_inputs = train_data_normalized[-train_cicle:].tolist()
print(test_inputs)
# Out:
# [-0.16030533611774445, -0.17557251453399658, -0.11832061409950256, -0.17557251453399658, -0.1679389327764511, -0.18320611119270325, -0.1564885526895523, -0.14885495603084564, -0.16030533611774445, -0.12595419585704803, -0.12595419585704803, -0.12977099418640137, -0.1335877925157547, -0.10687022656202316, -0.11832061409950256, -0.1450381726026535, -0.12595419585704803, -0.1335877925157547, -0.1335877925157547, -0.12595419585704803, -0.14122137427330017, -0.13740457594394684, -0.17938931286334991, -0.16412213444709778, -0.17557251453399658, -0.17938931286334991, -0.22900763154029846, -0.25190839171409607, -0.221374049782753, -0.21755725145339966]

# %%
#test_inputs

# %%
model.eval()

for i in range(fut_pred):
    seq = torch.FloatTensor(test_inputs[-train_cicle:])
    with torch.no_grad():
        model.hidden = (torch.zeros(1, 1, model.hidden_layer_size),
                        torch.zeros(1, 1, model.hidden_layer_size))
        print(model(seq))
        test_inputs.append(model(seq).item())
# Out:
# tensor([-0.2197])
# tensor([-0.2223])
# tensor([-0.2245])
# tensor([-0.2266])
# tensor([-0.2287])
# tensor([-0.2307])
# tensor([-0.2327])
# tensor([-0.2346])
# tensor([-0.2364])
# tensor([-0.2380])
# tensor([-0.2396])
# tensor([-0.2410])
# tensor([-0.2423])
# tensor([-0.2435])
# tensor([-0.2446])
# tensor([-0.2455])
# tensor([-0.2464])
# tensor([-0.2472])
# tensor([-0.2480])
# tensor([-0.2487])
# tensor([-0.2493])
# tensor([-0.2499])
# tensor([-0.2504])
# tensor([-0.2509])
# tensor([-0.2513])
# tensor([-0.2518])
# tensor([-0.2521])
# tensor([-0.2525])
# tensor([-0.2528])
# tensor([-0.2531])
# tensor([-0.2534])
# tensor([-0.2536])
# tensor([-0.2538])
# tensor([-0.2540])
# tensor([-0.2541])
# tensor([-0.2543])
# tensor([-0.2544])
# tensor([-0.2545])
# tensor([-0.2546])
# tensor([-0.2547])
# tensor([-0.2548])
# tensor([-0.2549])
# tensor([-0.2550])
# tensor([-0.2550])
# tensor([-0.2551])
# tensor([-0.2551])
# tensor([-0.2551])
# tensor([-0.2552])
# tensor([-0.2552])
# tensor([-0.2552])
# tensor([-0.2553])
# tensor([-0.2553])
# tensor([-0.2553])
# tensor([-0.2553])
# tensor([-0.2553])
# tensor([-0.2553])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])
# tensor([-0.2554])

# %%
test_inputs[fut_pred:]
# Out:
# [-0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516,
#  -0.2554244101047516]

# %%
actual_predictions = scaler.inverse_transform(np.array(test_inputs[train_cicle:] ).reshape(-1, 1))
#actual_predictions = scaler.inverse_transform(np.array(test_inputs[train_cicle:] ).reshape(-1, 1))
print(actual_predictions)
# Out:
# [[30.54327237]
#  [30.53755301]
#  [30.53171302]
#  [30.52633199]
#  [30.5209138 ]
#  [30.51552629]
#  [30.51032306]
#  [30.50536367]
#  [30.50069491]
#  [30.49634613]
#  [30.4923167 ]
#  [30.48860687]
#  [30.48521584]
#  [30.48212465]
#  [30.47928621]
#  [30.47669919]
#  [30.47435665]
#  [30.47222251]
#  [30.47028264]
#  [30.46851002]
#  [30.46687616]
#  [30.46536675]
#  [30.46396572]
#  [30.46268971]
#  [30.46150973]
#  [30.46041377]
#  [30.4593962 ]
#  [30.45847726]
#  [30.45764154]
#  [30.45688868]
#  [30.45621202]
#  [30.45560524]
#  [30.45506202]
#  [30.45457682]
#  [30.45414386]
#  [30.45375805]
#  [30.45341449]
#  [30.4531088 ]
#  [30.45283723]
#  [30.45259596]
#  [30.45238178]
#  [30.45219173]
#  [30.4520233 ]
#  [30.45187401]
#  [30.45174197]
#  [30.45162509]
#  [30.45152178]
#  [30.45143058]
#  [30.45135016]
#  [30.45127918]
#  [30.45121672]
#  [30.45116175]
#  [30.45111357]
#  [30.45107117]
#  [30.45103416]
#  [30.45100183]
#  [30.45097341]
#  [30.45094874]
#  [30.45092711]
#  [30.45090829]
#  [30.45089189]
#  [30.45087768]
#  [30.45086535]
#  [30.45085465]
#  [30.45084536]
#  [30.45083732]
#  [30.45083037]
#  [30.45082435]
#  [30.45081912]
#  [30.45081459]
#  [30.45081069]
#  [30.45080733]
#  [30.45080444]
#  [30.45080194]
#  [30.45079984]
#  [30.45079804]
#  [30.45079648]
#  [30.45079515]
#  [30.45079398]
#  [30.45079304]
#  [30.45079226]
#  [30.45079164]
#  [30.45079101]
#  [30.45079047]
#  [30.45079015]
#  [30.45078976]
#  [30.45078945]
#  [30.45078914]
#  [30.4507889 ]
#  [30.45078867]
#  [30.45078851]
#  [30.45078836]
#  [30.45078828]
#  [30.4507882 ]
#  [30.4507882 ]
#  [30.45078812]
#  [30.4507882 ]
#  [30.4507882 ]
#  [30.45078812]
#  [30.4507882 ]
#  [30.45078812]
#  [30.45078812]
#  [30.45078812]
#  [30.45078812]
#  [30.45078805]
#  [30.45078805]
#  [30.45078812]
#  [30.45078812]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]
#  [30.45078805]]

# %%
x = np.arange(2000, 2504, 1)
print(x)
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026 2027
#  2028 2029 2030 2031 2032 2033 2034 2035 2036 2037 2038 2039 2040 2041
#  2042 2043 2044 2045 2046 2047 2048 2049 2050 2051 2052 2053 2054 2055
#  2056 2057 2058 2059 2060 2061 2062 2063 2064 2065 2066 2067 2068 2069
#  2070 2071 2072 2073 2074 2075 2076 2077 2078 2079 2080 2081 2082 2083
#  2084 2085 2086 2087 2088 2089 2090 2091 2092 2093 2094 2095 2096 2097
#  2098 2099 2100 2101 2102 2103 2104 2105 2106 2107 2108 2109 2110 2111
#  2112 2113 2114 2115 2116 2117 2118 2119 2120 2121 2122 2123 2124 2125
#  2126 2127 2128 2129 2130 2131 2132 2133 2134 2135 2136 2137 2138 2139
#  2140 2141 2142 2143 2144 2145 2146 2147 2148 2149 2150 2151 2152 2153
#  2154 2155 2156 2157 2158 2159 2160 2161 2162 2163 2164 2165 2166 2167
#  2168 2169 2170 2171 2172 2173 2174 2175 2176 2177 2178 2179 2180 2181
#  2182 2183 2184 2185 2186 2187 2188 2189 2190 2191 2192 2193 2194 2195
#  2196 2197 2198 2199 2200 2201 2202 2203 2204 2205 2206 2207 2208 2209
#  2210 2211 2212 2213 2214 2215 2216 2217 2218 2219 2220 2221 2222 2223
#  2224 2225 2226 2227 2228 2229 2230 2231 2232 2233 2234 2235 2236 2237
#  2238 2239 2240 2241 2242 2243 2244 2245 2246 2247 2248 2249 2250 2251
#  2252 2253 2254 2255 2256 2257 2258 2259 2260 2261 2262 2263 2264 2265
#  2266 2267 2268 2269 2270 2271 2272 2273 2274 2275 2276 2277 2278 2279
#  2280 2281 2282 2283 2284 2285 2286 2287 2288 2289 2290 2291 2292 2293
#  2294 2295 2296 2297 2298 2299 2300 2301 2302 2303 2304 2305 2306 2307
#  2308 2309 2310 2311 2312 2313 2314 2315 2316 2317 2318 2319 2320 2321
#  2322 2323 2324 2325 2326 2327 2328 2329 2330 2331 2332 2333 2334 2335
#  2336 2337 2338 2339 2340 2341 2342 2343 2344 2345 2346 2347 2348 2349
#  2350 2351 2352 2353 2354 2355 2356 2357 2358 2359 2360 2361 2362 2363
#  2364 2365 2366 2367 2368 2369 2370 2371 2372 2373 2374 2375 2376 2377
#  2378 2379 2380 2381 2382 2383 2384 2385 2386 2387 2388 2389 2390 2391
#  2392 2393 2394 2395 2396 2397 2398 2399 2400 2401 2402 2403 2404 2405
#  2406 2407 2408 2409 2410 2411 2412 2413 2414 2415 2416 2417 2418 2419
#  2420 2421 2422 2423 2424 2425 2426 2427 2428 2429 2430 2431 2432 2433
#  2434 2435 2436 2437 2438 2439 2440 2441 2442 2443 2444 2445 2446 2447
#  2448 2449 2450 2451 2452 2453 2454 2455 2456 2457 2458 2459 2460 2461
#  2462 2463 2464 2465 2466 2467 2468 2469 2470 2471 2472 2473 2474 2475
#  2476 2477 2478 2479 2480 2481 2482 2483 2484 2485 2486 2487 2488 2489
#  2490 2491 2492 2493 2494 2495 2496 2497 2498 2499 2500 2501 2502 2503]

# %%
plt.title('predict')
plt.ylabel('Rate')
plt.grid(True)
plt.autoscale(axis='x', tight=True)
plt.plot(df['DEXTAUS'])
plt.plot(x, actual_predictions)
plt.show()
